# %%
#!/usr/bin/env python
import pika

# %%
connection = pika.BlockingConnection(pika.ConnectionParameters('localhost'))
channel = connection.channel()

# %%
# create a queue call hello in RabbitMQ
channel.queue_declare(queue='hello')

# can use 
# sudo docker exec -it rabbitmq rabbitmqctl list_queues
# to check the queue in docker image
# Out:
# <METHOD(['channel_number=1', 'frame_type=1', "method=<Queue.DeclareOk(['consumer_count=0', 'message_count=1', 'queue=hello'])>"])>

# %%
def callback(ch, method, properties, body):
    print(f" [x] Received {body}")

# %%
channel.basic_consume(queue='hello',
                      auto_ack=True,
                      on_message_callback=callback)
# Out:
# 'ctag1.e0c5ebf0cf4d430090aa179ffe068d16'

# %%
print(' [*] Waiting for messages. To exit press CTRL+C')
channel.start_consuming()
# Out:
#  [*] Waiting for messages. To exit press CTRL+C
#  [x] Received b'Hello World!'
#  [x] Received b'Hello World!'
#  [x] Received b'Hello World! (0)'
#  [x] Received b'Hello World! (1)'
#  [x] Received b'Hello World! (2)'
#  [x] Received b'Hello World! (3)'
#  [x] Received b'Hello World! (4)'
#  [x] Received b'Hello World! (5)'
#  [x] Received b'Hello World! (6)'
#  [x] Received b'Hello World! (7)'
#  [x] Received b'Hello World! (8)'
#  [x] Received b'Hello World! (9)'
#  [x] Received b'Hello World! (10)'
#  [x] Received b'Hello World! (11)'
#  [x] Received b'Hello World! (12)'
#  [x] Received b'Hello World! (13)'
#  [x] Received b'Hello World! (14)'
#  [x] Received b'Hello World! (15)'
#  [x] Received b'Hello World! (16)'
#  [x] Received b'Hello World! (17)'
#  [x] Received b'Hello World! (18)'
#  [x] Received b'Hello World! (19)'
#  [x] Received b'Hello World! (20)'
#  [x] Received b'Hello World! (21)'
#  [x] Received b'Hello World! (22)'
#  [x] Received b'Hello World! (23)'
#  [x] Received b'Hello World! (24)'
#  [x] Received b'Hello World! (25)'
#  [x] Received b'Hello World! (26)'
#  [x] Received b'Hello World! (27)'
#  [x] Received b'Hello World! (28)'
#  [x] Received b'Hello World! (29)'
#  [x] Received b'Hello World! (30)'
#  [x] Received b'Hello World! (31)'
#  [x] Received b'Hello World! (32)'
#  [x] Received b'Hello World! (33)'
#  [x] Received b'Hello World! (34)'
#  [x] Received b'Hello World! (35)'
#  [x] Received b'Hello World! (36)'
#  [x] Received b'Hello World! (37)'
#  [x] Received b'Hello World! (38)'
#  [x] Received b'Hello World! (39)'
#  [x] Received b'Hello World! (40)'
#  [x] Received b'Hello World! (41)'
#  [x] Received b'Hello World! (42)'
#  [x] Received b'Hello World! (43)'
#  [x] Received b'Hello World! (44)'
#  [x] Received b'Hello World! (45)'
#  [x] Received b'Hello World! (46)'
#  [x] Received b'Hello World! (47)'
#  [x] Received b'Hello World! (48)'
#  [x] Received b'Hello World! (49)'
#  [x] Received b'Hello World! (50)'
#  [x] Received b'Hello World! (51)'
#  [x] Received b'Hello World! (52)'
#  [x] Received b'Hello World! (53)'
#  [x] Received b'Hello World! (54)'
#  [x] Received b'Hello World! (55)'
#  [x] Received b'Hello World! (56)'
#  [x] Received b'Hello World! (57)'
#  [x] Received b'Hello World! (58)'
#  [x] Received b'Hello World! (59)'
#  [x] Received b'Hello World! (60)'
#  [x] Received b'Hello World! (61)'
#  [x] Received b'Hello World! (62)'
#  [x] Received b'Hello World! (63)'
#  [x] Received b'Hello World! (64)'
#  [x] Received b'Hello World! (65)'
#  [x] Received b'Hello World! (66)'
#  [x] Received b'Hello World! (67)'
#  [x] Received b'Hello World! (68)'
#  [x] Received b'Hello World! (69)'
#  [x] Received b'Hello World! (70)'
#  [x] Received b'Hello World! (71)'
#  [x] Received b'Hello World! (72)'
#  [x] Received b'Hello World! (73)'
#  [x] Received b'Hello World! (74)'
#  [x] Received b'Hello World! (75)'
#  [x] Received b'Hello World! (76)'
#  [x] Received b'Hello World! (77)'
#  [x] Received b'Hello World! (78)'
#  [x] Received b'Hello World! (79)'
#  [x] Received b'Hello World! (80)'
#  [x] Received b'Hello World! (81)'
#  [x] Received b'Hello World! (82)'
#  [x] Received b'Hello World! (83)'
#  [x] Received b'Hello World! (84)'
#  [x] Received b'Hello World! (85)'
#  [x] Received b'Hello World! (86)'
#  [x] Received b'Hello World! (87)'
#  [x] Received b'Hello World! (88)'
#  [x] Received b'Hello World! (89)'
#  [x] Received b'Hello World! (90)'
#  [x] Received b'Hello World! (91)'
#  [x] Received b'Hello World! (92)'
#  [x] Received b'Hello World! (93)'
#  [x] Received b'Hello World! (94)'
#  [x] Received b'Hello World! (95)'
#  [x] Received b'Hello World! (96)'
#  [x] Received b'Hello World! (97)'
#  [x] Received b'Hello World! (98)'
#  [x] Received b'Hello World! (99)'
