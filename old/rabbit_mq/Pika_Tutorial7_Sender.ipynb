# %%
#!/usr/bin/env python
import pika
import sys

# %%
connection = pika.BlockingConnection(
    pika.ConnectionParameters(host='localhost'))
channel = connection.channel()

# %%
channel.exchange_declare(exchange='topic_logs', exchange_type='topic')
# Out:
# <METHOD(['channel_number=1', 'frame_type=1', 'method=<Exchange.DeclareOk>'])>

# %%
routing_key = 'anonymous.info'
message = 'Hello World!'

# %%
channel.basic_publish(
    exchange='topic_logs', routing_key=routing_key, body=message)
print(f" [x] Sent {routing_key}:{message}")
# Out:
#  [x] Sent anonymous.info:Hello World!

# %%
routing_key = "kern.critical" 
message = "A critical kernel error"

# %%
channel.basic_publish(
    exchange='topic_logs', routing_key=routing_key, body=message)
print(f" [x] Sent {routing_key}:{message}")
# Out:
#  [x] Sent kern.critical:A critical kernel error

# %%
routing_key = 'anonymous.critical'
message = 'anony crit hello!'

# %%
channel.basic_publish(
    exchange='topic_logs', routing_key=routing_key, body=message)
print(f" [x] Sent {routing_key}:{message}")
# Out:
#  [x] Sent anonymous.critical:anony crit hello!

# %%
routing_key = 'kern.info'
message = 'Hello Kernal!'

# %%
channel.basic_publish(
    exchange='topic_logs', routing_key=routing_key, body=message)
print(f" [x] Sent {routing_key}:{message}")
# Out:
#  [x] Sent kern.info:Hello Kernal!

# %%
connection.close()
