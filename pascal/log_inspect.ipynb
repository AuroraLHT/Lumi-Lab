# %%
ls
# Out:
# auto_log.py                      __init__.py                simulate_log.py
# auto_log_reading.ipynb           log_fields.json            storage/
# auto_log_storage_rabbitMQ.ipynb  log_inspect.ipynb          test_auto.csv
# auto_storage.py                  parse_log.ipynb            test_command.ipynb
# auto_upload_rabbitMQ.ipynb       _PLD_Operation_Manual.pdf  test_command.py
# chamber_log2.csv                 __pycache__/               test_log.csv
# chamber_log.py                   README.md
# command.py                       simulate_log.ipynb

# %%
import pandas as pd
